# %%
#How do I apply multiple filter criteria to a pandas DataFrame

# %%
import pandas as pd

# %%
movies=pd.read_csv('imdb_1000.csv')

# %%
movies
# Out:
#      star_rating                                              title  \
# 0            9.3                           The Shawshank Redemption
# 1            9.2                                      The Godfather
# 2            9.1                             The Godfather: Part II
# 3            9.0                                    The Dark Knight
# 4            8.9                                       Pulp Fiction
# 5            8.9                                       12 Angry Men
# 6            8.9                     The Good, the Bad and the Ugly
# 7            8.9      The Lord of the Rings: The Return of the King
# 8            8.9                                   Schindler's List
# 9            8.9                                         Fight Club
# 10           8.8  The Lord of the Rings: The Fellowship of the Ring
# 11           8.8                                          Inception
# 12           8.8     Star Wars: Episode V - The Empire Strikes Back
# ...

# %%
movies[movies.duration>210]
# Out:
#      star_rating                              title content_rating      genre  \
# 78           8.4        Once Upon a Time in America              R      Crime
# 85           8.4                 Lawrence of Arabia             PG  Adventure
# 142          8.3  Lagaan: Once Upon a Time in India             PG  Adventure
# 157          8.2                 Gone with the Wind              G      Drama
# 204          8.1                            Ben-Hur              G  Adventure
# 445          7.9               The Ten Commandments       APPROVED  Adventure
# 476          7.8                             Hamlet          PG-13      Drama
#
#      duration                                        actors_list
# 78        229  [u'Robert De Niro', u'James Woods', u'Elizabet...
# 85        216  [u"Peter O'Toole", u'Alec Guinness', u'Anthony...
# 142       224  [u'Aamir Khan', u'Gracy Singh', u'Rachel Shell...
# 157       238  [u'Clark Gable', u'Vivien Leigh', u'Thomas Mit...
# ...

# %%
# CORRECT: use the '&' operator to specify that both conditions are required
# DURATION>210 AND GENRE "ADVEBTURE"

# %%
movies[(movies.duration>=210) & (movies.genre=='Adventure') & (movies['content_rating']=='PG')]
# Out:
#      star_rating                              title content_rating      genre  \
# 85           8.4                 Lawrence of Arabia             PG  Adventure
# 142          8.3  Lagaan: Once Upon a Time in India             PG  Adventure
#
#      duration                                        actors_list
# 85        216  [u"Peter O'Toole", u'Alec Guinness', u'Anthony...
# 142       224  [u'Aamir Khan', u'Gracy Singh', u'Rachel Shell...

# %%
#**Goal:** Filter the original DataFrame to show movies with a 'genre' of 'Crime' or 'Drama' or 'Action'

# %%
movies[((movies.genre=='Crime')| (movies.genre=='Drama') | (movies.genre=='Action')) & (movies.duration>=200)]
# Out:
#      star_rating                            title content_rating   genre  \
# 2            9.1           The Godfather: Part II              R   Crime
# 17           8.7                    Seven Samurai        UNRATED   Drama
# 78           8.4      Once Upon a Time in America              R   Crime
# 157          8.2               Gone with the Wind              G   Drama
# 476          7.8                           Hamlet          PG-13   Drama
# 767          7.6  It's a Mad, Mad, Mad, Mad World       APPROVED  Action
#
#      duration                                        actors_list
# 2         200  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 17        207  [u'Toshir\xf4 Mifune', u'Takashi Shimura', u'K...
# 78        229  [u'Robert De Niro', u'James Woods', u'Elizabet...
# 157       238  [u'Clark Gable', u'Vivien Leigh', u'Thomas Mit...
# 476       242  [u'Kenneth Branagh', u'Julie Christie', u'Dere...
# 767       205  [u'Spencer Tracy', u'Milton Berle', u'Ethel Me...

# %%
# use the '|' operator to specify that a row can match any of the three criteria
movies[(movies.genre == 'Crime') | (movies.genre == 'Drama') | (movies.genre == 'Action')].head(10)
# Out:
#     star_rating                                           title  \
# 0           9.3                        The Shawshank Redemption
# 1           9.2                                   The Godfather
# 2           9.1                          The Godfather: Part II
# 3           9.0                                 The Dark Knight
# 4           8.9                                    Pulp Fiction
# 5           8.9                                    12 Angry Men
# 9           8.9                                      Fight Club
# 11          8.8                                       Inception
# 12          8.8  Star Wars: Episode V - The Empire Strikes Back
# 13          8.8                                    Forrest Gump
#
#    content_rating   genre  duration  \
# 0               R   Crime       142
# 1               R   Crime       175
# 2               R   Crime       200
# 3           PG-13  Action       152
# 4               R   Crime       154
# 5       NOT RATED   Drama        96
# ...

# %%
# or equivalently, use the 'isin' method
movies[movies.genre.isin(['Crime','Drama','Action'])]
# You can see the result the same above
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# 5            8.9                                     12 Angry Men
# 9            8.9                                       Fight Club
# 11           8.8                                        Inception
# 12           8.8   Star Wars: Episode V - The Empire Strikes Back
# 13           8.8                                     Forrest Gump
# 16           8.7                  One Flew Over the Cuckoo's Nest
# 17           8.7                                    Seven Samurai
# 19           8.7                                        Star Wars
# ...
