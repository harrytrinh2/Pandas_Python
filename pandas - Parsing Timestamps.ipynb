# %% [markdown]
# # pandas - Parsing Timestamps

# %%
import pandas as pd
import numpy as np

# %%
# %matplotlib inline

# %% [markdown]
# chronological = theo thời gian

# %% [markdown]
# Timestamps are common in sensor data or other time series datasets.

# %%
tags=pd.read_csv("ml-20m/tags.csv",sep=",")
tags.dtypes
# Out:
# userId        int64
# movieId       int64
# tag          object
# timestamp     int64
# dtype: object

# %% [markdown]
# minh co the thay timestamp o day co dinh dang int64, nen gio minh se convert

# %%
tags["parsed_time"]=pd.to_datetime(tags["timestamp"],unit='s')

# %%
tags["parsed_time"].dtypes
# Out:
# dtype('<M8[ns]')

# %% [markdown]
# u' u`, da chuyen dinh dang int64 sang datetime64[ns]

# %%
tags.head()
# Out:
#    userId  movieId            tag   timestamp         parsed_time
# 0      18     4141    Mark Waters  1240597180 2009-04-24 18:19:40
# 1      65      208      dark hero  1368150078 2013-05-10 01:41:18
# 2      65      353      dark hero  1368150079 2013-05-10 01:41:19
# 3      65      521  noir thriller  1368149983 2013-05-10 01:39:43
# 4      65      592      dark hero  1368150078 2013-05-10 01:41:18

# %% [markdown]
# #kieu du lieu ban dau timestamp o day la, kieu interger

# %% [markdown]
# # selecting rows based on timestamps

# %%
greater_than_t=tags["parsed_time"]> '2015-02-01'
select_rows=tags[greater_than_t]
tags.shape,select_rows.shape
# Out:
# ((465564, 5), (12130, 5))

# %% [markdown]
# o day co nghia la co 12130 hang co so ngay lon hon 2015-02-01

# %%
select_rows
# Out:
#         userId  movieId                       tag   timestamp  \
# 301        318      260                     1970s  1424472169
# 302        318      260                   fantasy  1424472169
# 303        318      260                    sci-fi  1424472169
# 304        318   115149                    Action  1424534310
# 305        318   115149                   Revenge  1424534283
# 306        318   115149              Willem Dafoe  1424534383
# 324        342      318                masterplan  1423424898
# 326        342      318             prison escape  1423424898
# 327        342      318                redemption  1423424898
# 589        342   108190           based on a book  1426978115
# 590        342   108190                  dystopia  1426978076
# 1018       370     6975  breaking the fourth wall  1425242234
# 1019       370    27592                   violent  1425241975
# 2203       969       97            class conflict  1426754226
# ...

# %% [markdown]
# # sorting the table using the timestamps

# %%
tags.sort_values(by="parsed_time",ascending=False)[:10]
# Out:
#         userId  movieId                              tag   timestamp  \
# 339178  102853   115149                    russian mafia  1427771352
# 158780   46072     6058                      premonition  1427760764
# 158763   46072     3409                      premonition  1427760726
# 288375   87797      215                           Vienna  1427755801
# 290535   88044   106782                        profanity  1427754096
# 290527   88044   106782                            crime  1427753921
# 290526   88044   106782                           Amoral  1427753913
# 290531   88044   106782                       Jonah Hill  1427753849
# 290530   88044   106782                       inaccurate  1427753806
# 290528   88044   106782  Economically Illiterate Writers  1427753739
#
#                parsed_time
# 339178 2015-03-31 03:09:12
# 158780 2015-03-31 00:12:44
# 158763 2015-03-31 00:12:06
# 288375 2015-03-30 22:50:01
# 290535 2015-03-30 22:21:36
# 290527 2015-03-30 22:18:41
# ...

# %% [markdown]
# sap xep xem thang nao gan day nhat(moi nhat)

# %% [markdown]
# # Average movie ratings over Time

# %% [markdown]
# Are movie ratings related to the year of launch?

# %%
ratings=pd.read_csv("ml-20m/ratings.csv",sep=",")
average_rating=ratings[['movieId','rating']].groupby('movieId',as_index=False)

# %%
average_rating.tail()
# Out:
#           movieId  rating
# 8843        27359     2.5
# 21166        3332     3.0
# 27111       91213     1.0
# 27152      107881     2.5
# 27154      109492     3.5
# 29578      100946     4.5
# 31739       46957     3.5
# 31814       83417     3.5
# 31863      100062     3.5
# 33559      107230     5.0
# 46231       68337     4.0
# 46326       83291     4.0
# 60901       98217     2.5
# 62737       77355     1.0
# 65337       38839     3.0
# 65416       80330     3.0
# 65472       91981     3.5
# 65510       99904     1.0
# 65517      103361     3.5
# 65518      104064     3.5
# 65519      104066     3.0
# 65520      104464     4.0
# 65521      104638     1.5
# 65522      105753     3.5
# 69410       88061     3.0
# 72715       43248     1.0
# 72739       87591     4.0
# 72744       93816     4.0
# 79282       40679     2.0
# 79318       44892     1.5
# ...           ...     ...
# 20000233    50872     3.5
# 20000234    51086     3.5
# 20000235    51662     4.5
# ...

# %%
movies=pd.read_csv("ml-20m/movies.csv",sep=",")

# %%
joined=movies.merge(average_rating, on='movieId',how='inner')
joined.head()
joined.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-fab3b6b1eed6> in <module>()
# ----> 1 joined=movies.merge(average_rating, on='movieId',how='inner')
#       2 joined.head()
#       3 joined.corr()
#
# ~/.local/lib/python3.5/site-packages/pandas/core/frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator)
#    4720                      right_on=right_on, left_index=left_index,
#    4721                      right_index=right_index, sort=sort, suffixes=suffixes,
# -> 4722                      copy=copy, indicator=indicator)
#    4723
#    4724     def round(self, decimals=0, *args, **kwargs):
#
# ~/.local/lib/python3.5/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator)
# ...
