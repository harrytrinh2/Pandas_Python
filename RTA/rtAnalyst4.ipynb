# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 372F-3690
#
#  Directory of C:\Users\USER\Documents\Py_Project\RTA\problem 4
#
# 03/18/2018  12:20 AM    <DIR>          .
# 03/18/2018  12:20 AM    <DIR>          ..
# 03/18/2018  12:20 AM    <DIR>          .ipynb_checkpoints
# 03/18/2018  12:19 AM            31,513 farm_management.xlsx
# 03/18/2018  12:20 AM                72 Untitled.ipynb
#                2 File(s)         31,585 bytes
#                3 Dir(s)  57,830,645,760 bytes free

# %%
import pandas as pd

# %%
data=pd.read_excel('farm_management.xlsx')
data
# Out:
#                  Mã luống                                          Tên luống  \
# 0    20170805162923609Sat  0101001 - Lô/Khu 01 - Thửa/nhà 01 - Luống 001 ...
# 1    20170805163135110Sat  0101002 - Lô/Khu 01 - Thửa/nhà 01 - Luống 002 ...
# 2    20170810155357254Thu  0101003 - Lô/Khu 01 - Thửa/nhà 01 - Luống 003 ...
# 3    20170925105340422Mon  0104005 - Lô/Khu 01 - Thửa/nhà 04 - Luống 005 ...
# 4    20170903194225798Sun  0202001 - Lô/Khu 02 - Thửa/nhà 02 - Luống 001 ...
# 5    20170816135446633Wed  0303002 - Lô/Khu 03 - Thửa/nhà 03 - Luống 002 ...
# 6    20170816141801545Wed  0303004 - Lô/Khu 03 - Thửa/nhà 03 - Luống 004 ...
# 7    20170816142124162Wed  0303006 - Lô/Khu 03 - Thửa/nhà 03 - Luống 006 ...
# 8    20170816143428135Wed  0303008 - Lô/Khu 03 - Thửa/nhà 03 - Luống 008 ...
# 9    20170816144548633Wed  0303010 - Lô/Khu 03 - Thửa/nhà 03 - Luống 010 ...
# 10   20170816145129249Wed  0303012 - Lô/Khu 03 - Thửa/nhà 03 - Luống 012 ...
# ...

# %% [markdown]
# # #1 Can you tell me which farm have higher performance and which do not?

# %% [markdown]
# #### well, in my opinion, These farms that havest  on time, which is higher performance than others

# %% [markdown]
# #### And another idea is that we can compare the quantity of each same produce. Or we can devide in average. If the quantity of the produce is higher median, we can conclude that produce is productive

# %% [markdown]
# # #2 Can you tell me which field lots are productive and which are not?

# %% [markdown]
# #### we can devide in average. If the quantity of the produce is higher median, we can conclude that produce is productive

# %% [markdown]
# #### But this dataset is missing too much info in 'Sản Lượng' column

# %% [markdown]
# # #3 Can you tell me which crops yeild high income and which are not?

# %% [markdown]
# #### There is no selling price so i can predict which crops yeild high income
