# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 372F-3690
#
#  Directory of C:\Users\USER\Documents\Py_Project\RTA
#
# 03/17/2018  10:34 PM    <DIR>          .
# 03/17/2018  10:34 PM    <DIR>          ..
# 03/17/2018  10:34 PM    <DIR>          .ipynb_checkpoints
# 10/26/2017  06:06 AM             8,473 Codebook.xlsx
# 03/17/2018  08:14 PM           129,725 CSDL_KhachHang.xlsx
# 10/26/2017  06:06 AM            20,803 rta_hiring.csv
# 03/17/2018  10:16 PM           390,332 rtAnalyst1.ipynb
# 03/17/2018  10:34 PM                72 rtAnalyst2.ipynb
#                5 File(s)        549,405 bytes
#                3 Dir(s)  57,838,788,608 bytes free

# %%
import pandas as pd

# %%
data=pd.read_csv('rta_hiring.csv')

# %%
data
# Out:
#                                      instanceID          rta_position  \
# 0     uuid:0d9467de-cde5-41f9-be08-26f94bd92141             rtAnalyst
# 1     uuid:2746835d-0a6f-4e78-b455-28451b553e08            HR - Admin
# 2     uuid:cdeb1f0b-3032-4a9b-93f2-d9d53a3173ad           rtSupporter
# 3     uuid:11756ea4-9d9b-4525-b9ef-80171e442980           rtSupporter
# 4     uuid:98f205fb-ccc4-4925-9180-ad737c64a6e1              rtIntern
# 5     uuid:69bd572d-28de-43fa-a355-eae025011049             rtAnalyst
# 6     uuid:f879a64f-380b-4555-ae44-cef71731ed2b              rtIntern
# 7     uuid:6fe72689-28e5-4159-83b6-34a3ce828d0a             rtAnalyst
# 8     uuid:d9c633d2-e1e9-4e12-b53b-9e85ad83d255            HR - Admin
# 9   uuid:67bc0713-aff6-4942-82a6-3a79bf537a67~1           rtSupporter
# 10    uuid:2c1c8f18-041c-4d8e-820e-7ffb3670a1da           rtSupporter
# 11    uuid:30c0d5ba-87ad-46df-9830-6263ffb5cfba            HR - Admin
# ...

# %% [markdown]
# # #1 OUT PUT MUST BE AN EXCEL FILE

# %%
data.to_excel('rta_hiring.xlsx',encoding='utf-8')

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 372F-3690
#
#  Directory of C:\Users\USER\Documents\Py_Project\RTA
#
# 03/17/2018  10:37 PM    <DIR>          .
# 03/17/2018  10:37 PM    <DIR>          ..
# 03/17/2018  10:34 PM    <DIR>          .ipynb_checkpoints
# 10/26/2017  06:06 AM             8,473 Codebook.xlsx
# 03/17/2018  08:14 PM           129,725 CSDL_KhachHang.xlsx
# 10/26/2017  06:06 AM            20,803 rta_hiring.csv
# 03/17/2018  10:37 PM            16,281 rta_hiring.xlsx
# 03/17/2018  10:16 PM           390,332 rtAnalyst1.ipynb
# 03/17/2018  10:36 PM            82,495 rtAnalyst2.ipynb
#                6 File(s)        648,109 bytes
#                3 Dir(s)  57,838,100,480 bytes free

# %%
data=pd.read_excel('rta_hiring.xlsx')

# %%
data
# Out:
#                                      instanceID          rta_position  \
# 0     uuid:0d9467de-cde5-41f9-be08-26f94bd92141             rtAnalyst
# 1     uuid:2746835d-0a6f-4e78-b455-28451b553e08            HR - Admin
# 2     uuid:cdeb1f0b-3032-4a9b-93f2-d9d53a3173ad           rtSupporter
# 3     uuid:11756ea4-9d9b-4525-b9ef-80171e442980           rtSupporter
# 4     uuid:98f205fb-ccc4-4925-9180-ad737c64a6e1              rtIntern
# 5     uuid:69bd572d-28de-43fa-a355-eae025011049             rtAnalyst
# 6     uuid:f879a64f-380b-4555-ae44-cef71731ed2b              rtIntern
# 7     uuid:6fe72689-28e5-4159-83b6-34a3ce828d0a             rtAnalyst
# 8     uuid:d9c633d2-e1e9-4e12-b53b-9e85ad83d255            HR - Admin
# 9   uuid:67bc0713-aff6-4942-82a6-3a79bf537a67~1           rtSupporter
# 10    uuid:2c1c8f18-041c-4d8e-820e-7ffb3670a1da           rtSupporter
# 11    uuid:30c0d5ba-87ad-46df-9830-6263ffb5cfba            HR - Admin
# ...

# %% [markdown]
# # #2 The file has to contain enough data for them to:
# * contact Candidates
# * Take note special cases
# * transfer easily to other teams after controlling for customized access => <strong> sorry i dont understand this requirement </strong>

# %%
data=pd.read_excel('rta_hiring.xlsx')

# %%
data['contact_Candidates']=data.rta_fullname+" "+data.rta_email+" "+data.rta_hamlet+" "+data.rta_commune_lb+" "+data.rta_district_lb+ str(data.rta_phone1)

# %%
info_contact=data['contact_Candidates']

# %%
info_contact.to_frame(name='contact_Candidates').to_excel('contact_Candidates.xlsx',encoding='utf-8')

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 372F-3690
#
#  Directory of C:\Users\USER\Documents\Py_Project\RTA
#
# 03/17/2018  11:04 PM    <DIR>          .
# 03/17/2018  11:04 PM    <DIR>          ..
# 03/17/2018  10:34 PM    <DIR>          .ipynb_checkpoints
# 10/26/2017  06:06 AM             8,473 Codebook.xlsx
# 03/17/2018  11:05 PM             9,630 contact_Candidates.xlsx
# 03/17/2018  08:14 PM           129,725 CSDL_KhachHang.xlsx
# 10/26/2017  06:06 AM            20,803 rta_hiring.csv
# 03/17/2018  10:37 PM            16,281 rta_hiring.xlsx
# 03/17/2018  10:16 PM           390,332 rtAnalyst1.ipynb
# 03/17/2018  11:04 PM           175,517 rtAnalyst2.ipynb
#                7 File(s)        750,761 bytes
#                3 Dir(s)  57,843,261,440 bytes free

# %%
data=pd.read_excel('contact_Candidates.xlsx')
